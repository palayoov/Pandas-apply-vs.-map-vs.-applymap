# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
jobs = pd.read_csv('NYC_Jobs.csv',)

# %%
jobs.head()
# Out:
#    Job ID                         Agency Posting Type  # Of Positions  \
# 0  424339  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1  379094   NYC EMPLOYEES RETIREMENT SYS     External               1
# 2  520417          NYC HOUSING AUTHORITY     External               1
# 3  233549   NYC EMPLOYEES RETIREMENT SYS     External               1
# 4  510256        HUMAN RIGHTS COMMISSION     External               5
#
#                                   Business Title  \
# 0  Triage Nurse, Bureau of Public Health Clinics
# 1          CERTIFIED IT DEVELOPER (APPLICATIONS)
# 2                            Chief of Settlement
# 3  CERTIFIED IT ADMINISTRATOR (LAN/WAN), LEVEL 4
# 4              Associate Human Rights Specialist
#
#               Civil Service Title Title Classification Title Code No Level  \
# 0             PUBLIC HEALTH NURSE        Competitive-1         51011    03
# 1         CERT IT DEVELOPER (APP)        Competitive-1         13643    02
# ...

# %%
# Convert any columns that have nurse in the Business Title	to just Nurse

jobs['Business Title'].apply(lambda x: ('Nurse' if 'Nurse' in x else x))

# %%
def apply_everywhere(row):
    return str(row) + ' ' + "It's 2024!"

jobs.applymap(func=apply_everywhere)

# %%
jobs.dtypes

# %%
jobs.groupby('Agency')['# Of Positions'].count()

# %%
jobs.groupby('Agency').apply(lambda df: df['Job Category'].iloc[0])
# Out:
# C:\Users\vinoo\AppData\Local\Temp\ipykernel_28584\4110034163.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   jobs.groupby('Agency').apply(lambda df: df['Job Category'].iloc[0])
# Agency
# ADMIN FOR CHILDREN'S SVCS                                           Social Services
# ADMIN TRIALS AND HEARINGS                                             Legal Affairs
# BOARD OF CORRECTION               Policy, Research & Analysis Public Safety, Ins...
# BOROUGH PRESIDENT-QUEENS                      Engineering, Architecture, & Planning
# BUSINESS INTEGRITY COMMISSION                         Technology, Data & Innovation
# ...

# %%
jobs.groupby(['Title Classification'])['Salary Range To'].agg(['min', 'max'])
# Out:
#                                  min       max
# Title Classification
# Competitive-1                16.1400  241434.0
# Exempt-4                  70000.0000  238000.0
# Labor-3                      16.6264   55361.0
# Non-Competitive-5            15.0000  265000.0
# Pending Classification-2     28.0000  231974.0

# %%
jobs.groupby(['Agency', 'Posting Type'])[['Agency']].agg([len])
# Out:
#                                            Agency
#                                               len
# Agency                        Posting Type
# ADMIN FOR CHILDREN'S SVCS     External         12
#                               Internal         28
# ADMIN TRIALS AND HEARINGS     External         16
#                               Internal         16
# BOARD OF CORRECTION           External          3
# ...                                           ...
# PUBLIC ADMINISTRATOR-NEW YORK Internal          4
# TAXI & LIMOUSINE COMMISSION   External         45
#                               Internal         48
# TEACHERS RETIREMENT SYSTEM    External          8
#                               Internal          9
#
# [111 rows x 1 columns]

# %%
jobs.groupby(['Agency'])[['Agency']].min()
# Out:
#                                                         Agency
# Agency
# ADMIN FOR CHILDREN'S SVCS            ADMIN FOR CHILDREN'S SVCS
# ADMIN TRIALS AND HEARINGS            ADMIN TRIALS AND HEARINGS
# BOARD OF CORRECTION                        BOARD OF CORRECTION
# BOROUGH PRESIDENT-QUEENS              BOROUGH PRESIDENT-QUEENS
# BUSINESS INTEGRITY COMMISSION    BUSINESS INTEGRITY COMMISSION
# CAMPAIGN FINANCE BOARD                  CAMPAIGN FINANCE BOARD
# CIVIL SERVICE COMMISSION              CIVIL SERVICE COMMISSION
# CIVILIAN COMPLAINT REVIEW BD      CIVILIAN COMPLAINT REVIEW BD
# CONFLICTS OF INTEREST BOARD        CONFLICTS OF INTEREST BOARD
# CONSUMER AND WORKER PROTECTION  CONSUMER AND WORKER PROTECTION
# DEPARTMENT FOR THE AGING              DEPARTMENT FOR THE AGING
# DEPARTMENT OF BUILDINGS                DEPARTMENT OF BUILDINGS
# DEPARTMENT OF BUSINESS SERV.      DEPARTMENT OF BUSINESS SERV.
# DEPARTMENT OF CITY PLANNING        DEPARTMENT OF CITY PLANNING
# ...

# %%
# group by Agency, Posting Type, highest salary
jobs.groupby(['Agency', 'Posting Type'])[['Agency', 'Posting Type', 'Salary Range To']].apply(lambda df: df.loc[df['Salary Range To'].idxmax()])
# Out:
#                                                                    Agency  \
# Agency                        Posting Type
# ADMIN FOR CHILDREN'S SVCS     External          ADMIN FOR CHILDREN'S SVCS
#                               Internal          ADMIN FOR CHILDREN'S SVCS
# ADMIN TRIALS AND HEARINGS     External          ADMIN TRIALS AND HEARINGS
#                               Internal          ADMIN TRIALS AND HEARINGS
# BOARD OF CORRECTION           External                BOARD OF CORRECTION
# ...                                                                   ...
# PUBLIC ADMINISTRATOR-NEW YORK Internal      PUBLIC ADMINISTRATOR-NEW YORK
# TAXI & LIMOUSINE COMMISSION   External        TAXI & LIMOUSINE COMMISSION
#                               Internal        TAXI & LIMOUSINE COMMISSION
# TEACHERS RETIREMENT SYSTEM    External         TEACHERS RETIREMENT SYSTEM
#                               Internal         TEACHERS RETIREMENT SYSTEM
#
# ...

# %%
# stats on salary range to by Agency
jobs.groupby('Agency')['Salary Range To'].agg([len])
# Out:
#                                 len
# Agency
# ADMIN FOR CHILDREN'S SVCS        40
# ADMIN TRIALS AND HEARINGS        32
# BOARD OF CORRECTION               6
# BOROUGH PRESIDENT-QUEENS          4
# BUSINESS INTEGRITY COMMISSION     9
# CAMPAIGN FINANCE BOARD            2
# CIVIL SERVICE COMMISSION          2
# CIVILIAN COMPLAINT REVIEW BD     13
# CONFLICTS OF INTEREST BOARD       4
# CONSUMER AND WORKER PROTECTION   76
# DEPARTMENT FOR THE AGING         20
# DEPARTMENT OF BUILDINGS          86
# DEPARTMENT OF BUSINESS SERV.     15
# DEPARTMENT OF CITY PLANNING      83
# DEPARTMENT OF CORRECTION        213
# DEPARTMENT OF FINANCE            33
# DEPARTMENT OF INVESTIGATION      28
# DEPARTMENT OF PROBATION          16
# DEPARTMENT OF SANITATION         53
# DEPARTMENT OF TRANSPORTATION    197
# DEPT OF CITYWIDE ADMIN SVCS      39
# DEPT OF DESIGN & CONSTRUCTION   152
# DEPT OF ENVIRONMENT PROTECTION  588
# DEPT OF HEALTH/MENTAL HYGIENE   285
# DEPT OF INFO TECH & TELECOMM     41
# ...

# %%
job_sort_salary = jobs.groupby(['Agency', 'Posting Type'])['Salary Range To'].agg([len])

# %%
job_sort_salary.index
# Out:
# MultiIndex([(     'ADMIN FOR CHILDREN'S SVCS', 'External'),
#             (     'ADMIN FOR CHILDREN'S SVCS', 'Internal'),
#             (     'ADMIN TRIALS AND HEARINGS', 'External'),
#             (     'ADMIN TRIALS AND HEARINGS', 'Internal'),
#             (           'BOARD OF CORRECTION', 'External'),
#             (           'BOARD OF CORRECTION', 'Internal'),
#             (      'BOROUGH PRESIDENT-QUEENS', 'External'),
#             (      'BOROUGH PRESIDENT-QUEENS', 'Internal'),
#             ( 'BUSINESS INTEGRITY COMMISSION', 'External'),
#             ( 'BUSINESS INTEGRITY COMMISSION', 'Internal'),
#             ...
#             (             'POLICE DEPARTMENT', 'External'),
#             (             'POLICE DEPARTMENT', 'Internal'),
#             ('PRESIDENT BOROUGH OF MANHATTAN', 'External'),
#             ('PRESIDENT BOROUGH OF MANHATTAN', 'Internal'),
#             ( 'PUBLIC ADMINISTRATOR-NEW YORK', 'External'),
# ...

# %%
type(job_sort_salary.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
type(job_sort_salary.reset_index)
# Out:
# method

# %%
    job_sort_salary.sort_values(by='len', ascending=False)
# Out:
#                                              len
# Agency                         Posting Type
# DEPT OF ENVIRONMENT PROTECTION Internal      314
#                                External      274
# DEPT OF HEALTH/MENTAL HYGIENE  Internal      174
# NYC HOUSING AUTHORITY          Internal      155
#                                External      122
# ...                                          ...
# LANDMARKS PRESERVATION COMM    Internal        1
#                                External        1
# DEPT. OF HOMELESS SERVICES     Internal        1
# EQUAL EMPLOY PRACTICES COMM    External        1
# NYC FIRE PENSION FUND          Internal        1
#
# [111 rows x 1 columns]

# %%
jobs.groupby(['Agency','Business Title']).size()
# Out:
# Agency                      Business Title
# ADMIN FOR CHILDREN'S SVCS   APA Manager                                            1
#                             Agency Implementation and Support Program Evaluator    1
#                             Assistant Commissioner                                 1
#                             Associate Commissioner                                 1
#                             Attorney Interne                                       2
#                                                                                   ..
# TEACHERS RETIREMENT SYSTEM  Investment Operations Senior Analyst                   2
#                             Member Services College Aide                           2
#                             Senior Quality Assurance Engineer                      2
#                             Service Desk Technician                                2
# ...

# %%
jobs.describe()
# Out:
#               Job ID  # Of Positions  Salary Range From  Salary Range To  \
# count    3773.000000     3773.000000        3773.000000      3773.000000
# mean   500493.408693        2.614365       57657.939466     79660.249595
# std     48518.942211        9.781737       36629.729583     51101.248638
# min     87990.000000        1.000000           0.000000        15.000000
# 25%    496634.000000        1.000000       40017.000000     54228.000000
# 50%    518535.000000        1.000000       58700.000000     80000.000000
# 75%    524405.000000        1.000000       75000.000000    109409.000000
# max    528532.000000      250.000000      250000.000000    265000.000000
#
#        Recruitment Contact
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
jobs[jobs['Recruitment Contact'].isnull()]
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 0     424339   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1     379094    NYC EMPLOYEES RETIREMENT SYS     External               1
# 2     520417           NYC HOUSING AUTHORITY     External               1
# 3     233549    NYC EMPLOYEES RETIREMENT SYS     External               1
# 4     510256         HUMAN RIGHTS COMMISSION     External               5
# ...      ...                             ...          ...             ...
# 3768  457839    NYC EMPLOYEES RETIREMENT SYS     Internal               1
# 3769  527141  HOUSING PRESERVATION & DVLPMNT     Internal               1
# 3770  509443      FINANCIAL INFO SVCS AGENCY     Internal               1
# 3771  352367   DEPT OF HEALTH/MENTAL HYGIENE     Internal               2
# 3772  478739         HUMAN RIGHTS COMMISSION     External               1
#
#                                          Business Title  \
# ...

# %%
jobs['Recruitment Contact'].replace("Mr. T Money")
# Out:
# 0       Mr. T Money
# 1       Mr. T Money
# 2       Mr. T Money
# 3       Mr. T Money
# 4       Mr. T Money
#            ...
# 3768    Mr. T Money
# 3769    Mr. T Money
# 3770    Mr. T Money
# 3771    Mr. T Money
# 3772    Mr. T Money
# Name: Recruitment Contact, Length: 3773, dtype: object

# %%
jobs[jobs['Recruitment Contact'].isnull()]
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 0     424339   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1     379094    NYC EMPLOYEES RETIREMENT SYS     External               1
# 2     520417           NYC HOUSING AUTHORITY     External               1
# 3     233549    NYC EMPLOYEES RETIREMENT SYS     External               1
# 4     510256         HUMAN RIGHTS COMMISSION     External               5
# ...      ...                             ...          ...             ...
# 3768  457839    NYC EMPLOYEES RETIREMENT SYS     Internal               1
# 3769  527141  HOUSING PRESERVATION & DVLPMNT     Internal               1
# 3770  509443      FINANCIAL INFO SVCS AGENCY     Internal               1
# 3771  352367   DEPT OF HEALTH/MENTAL HYGIENE     Internal               2
# 3772  478739         HUMAN RIGHTS COMMISSION     External               1
#
#                                          Business Title  \
# ...

# %%
jobs
# Out:
#       Job ID                          Agency Posting Type  # Of Positions  \
# 0     424339   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1     379094    NYC EMPLOYEES RETIREMENT SYS     External               1
# 2     520417           NYC HOUSING AUTHORITY     External               1
# 3     233549    NYC EMPLOYEES RETIREMENT SYS     External               1
# 4     510256         HUMAN RIGHTS COMMISSION     External               5
# ...      ...                             ...          ...             ...
# 3768  457839    NYC EMPLOYEES RETIREMENT SYS     Internal               1
# 3769  527141  HOUSING PRESERVATION & DVLPMNT     Internal               1
# 3770  509443      FINANCIAL INFO SVCS AGENCY     Internal               1
# 3771  352367   DEPT OF HEALTH/MENTAL HYGIENE     Internal               2
# 3772  478739         HUMAN RIGHTS COMMISSION     External               1
#
#                                          Business Title  \
# ...

# %%
jobs.sum(axis=1)

# %%
salary_gb

# %%
jobs.groupby(['Agency'])['Agency'].count().sort_values(ascending=False)
jobs['Agency'].value_counts().sort_values(ascending=False)

# %%
jobs.rename(columns={'Agency': 'Agency_1'})

# %%
jobs.rename_axis('Agencies', axis='rows').rename_axis('Fields', axis='columns')
# Out:
# Fields    Job ID                          Agency Posting Type  # Of Positions  \
# Agencies
# 0         424339   DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 1         379094    NYC EMPLOYEES RETIREMENT SYS     External               1
# 2         520417           NYC HOUSING AUTHORITY     External               1
# 3         233549    NYC EMPLOYEES RETIREMENT SYS     External               1
# 4         510256         HUMAN RIGHTS COMMISSION     External               5
# ...          ...                             ...          ...             ...
# 3768      457839    NYC EMPLOYEES RETIREMENT SYS     Internal               1
# 3769      527141  HOUSING PRESERVATION & DVLPMNT     Internal               1
# 3770      509443      FINANCIAL INFO SVCS AGENCY     Internal               1
# 3771      352367   DEPT OF HEALTH/MENTAL HYGIENE     Internal               2
# 3772      478739         HUMAN RIGHTS COMMISSION     External               1
#
# ...
